# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/caschool.csv')
df
# Out:
#      observation_number  dist_cod       county  \
# 0                     1     75119      Alameda
# 1                     2     61499        Butte
# 2                     3     61549        Butte
# 3                     4     61457        Butte
# 4                     5     61523        Butte
# ..                  ...       ...          ...
# 415                 416     68957    San Mateo
# 416                 417     69518  Santa Clara
# 417                 418     72611      Ventura
# 418                 419     72744         Yuba
# 419                 420     72751         Yuba
#
#                             district gr_span  enrl_tot    teachers   calw_pct  \
# 0                 Sunol Glen Unified   KK-08       195   10.900000   0.510200
# 1               Manzanita Elementary   KK-08       240   11.150000  15.416700
# 2        Thermalito Union Elementary   KK-08      1550   82.900002  55.032299
# 3    Golden Feather Union Elementary   KK-08       243   14.000000  36.475399
# ...

# %%
deident_cols = ['county', 'district']
# unq_cols = df['county'].unique().tolist() + df['district'].unique().tolist()
unq_cols = [d for c in deident_cols for d in df[c].unique().tolist()]

prefix = 'A'
mapping_dict = {}
for i, col in enumerate(unq_cols):
    if col not in mapping_dict.keys():
        mapping_dict[col] = f'{prefix}_{i}'
for c in deident_cols:
    for i in range(df.shape[0]):
        df[c].iloc[i] = mapping_dict[df[c].iloc[i]]
# Out:
# /var/folders/4n/llv5s1w91lz35fsjb03m_g4w0000gn/T/ipykernel_56072/2766682581.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c].iloc[i] = mapping_dict[df[c].iloc[i]]

# %%
df
# Out:
#      observation_number  dist_cod county district gr_span  enrl_tot  \
# 0                     1     75119    A_0     A_45   KK-08       195
# 1                     2     61499    A_1     A_46   KK-08       240
# 2                     3     61549    A_1     A_47   KK-08      1550
# 3                     4     61457    A_1     A_48   KK-08       243
# 4                     5     61523    A_1     A_49   KK-08      1335
# ..                  ...       ...    ...      ...     ...       ...
# 415                 416     68957   A_13    A_449   KK-08       984
# 416                 417     69518   A_16    A_450   KK-08      3724
# 417                 418     72611   A_14    A_451   KK-08       441
# 418                 419     72744   A_44    A_452   KK-08       101
# 419                 420     72751   A_44    A_453   KK-08      1778
#
#        teachers   calw_pct   meal_pct  computer     testscr  comp_stu  \
# 0     10.900000   0.510200   2.040800        67  690.799988  0.343590
# ...

# %%
convert_mappting_dict = {}
keys = [k for k in mapping_dict.keys()]
values = [mapping_dict[k] for k in keys]
convert_mappting_dict['key'] = keys
convert_mappting_dict['value'] = values

mapping_table = pd.DataFrame.from_dict(convert_mappting_dict)
mapping_table
# Out:
#                         key  value
# 0                   Alameda    A_0
# 1                     Butte    A_1
# 2                    Fresno    A_2
# 3               San Joaquin    A_3
# 4                      Kern    A_4
# ..                      ...    ...
# 449  Las Lomitas Elementary  A_449
# 450    Los Altos Elementary  A_450
# 451  Somis Union Elementary  A_451
# 452       Plumas Elementary  A_452
# 453    Wheatland Elementary  A_453
#
# [454 rows x 2 columns]
